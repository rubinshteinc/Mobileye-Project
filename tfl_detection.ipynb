# %% [markdown]
# ## Hands on lecture: train TFL net
#
#  In this hands-on lecture, we will train a model for predicting Traffic-light (TFL) in image patches, you will use the data generated in previous course to this end.
#  You will :
#  1. Evaluate the data previously generated and ensure it's validity.
#  2. Train a CNN
#  3. Evaluate results of the trained model.
#  4. seek ways to improve results

# %%
# %reload_ext autoreload
# %autoreload 2
# %autosave 120
# %matplotlib inline
import numpy as np, matplotlib.pyplot as plt
from os.path import join
# Out:
# Autosaving every 120 seconds

# %% [markdown]
# ## Step 1. Validate your data
#     use the example in the cell below, to verify the TFL patch you've generated is sane.
#     Things to watch for:
#     1. You are able to load and vizualize your train and val data, using the functions below.
#     2. using the vizualization verify  image <--> label correspondence is correct.
#     3. % Negative vs. Positive examples is aprroximately 50%

# %%
def load_tfl_data(data_dir, crop_shape=(81,81)):
    images = np.memmap(join(data_dir,'data.bin'),mode='r',dtype=np.uint8).reshape([-1]+list(crop_shape) +[3])
    labels = np.memmap(join(data_dir,'labels.bin'),mode='r',dtype=np.uint8)
    return {'images':images,'labels':labels}

def viz_my_data(images,labels, predictions=None, num=(5,5), labels2name= {0:'No TFL',1:'Yes TFL'}):
    assert images.shape[0] == labels.shape[0]
    assert predictions is None or predictions.shape[0] == images.shape[0]
    h = 5
    n = num[0]*num[1]
    ax = plt.subplots(num[0],num[1],figsize=(h*num[0],h*num[1]),gridspec_kw={'wspace':0.05},squeeze=False,sharex=True,sharey=True)[1] #.flatten()
    idxs = np.random.randint(0,images.shape[0],n)
    for i,idx in enumerate(idxs):
        ax.flatten()[i].imshow(images[idx])
        title = labels2name[labels[idx]]
        if predictions is not None : title += ' Prediction: {:.2f}'.format(predictions[idx])
        ax.flatten()[i].set_title(title)
   

# root = './'  #this is the root for your val and train datasets
data_dir = "your path...."
datasets = {
    'val':load_tfl_data(join(data_dir,'val')),
    'train': load_tfl_data(join(data_dir,'train')),
    }

for k,v in datasets.items():
    print ('{} :  {} 0/1 split {:.1f} %'.format(k,v['images'].shape, np.mean(v['labels']==1)*100))

viz_my_data(num=(6,6),**datasets['val'])       


## define the model used for training
# Out:
# val :  (484, 81, 81, 3) 0/1 split 50.0 %
# train :  (7136, 81, 81, 3) 0/1 split 50.0 %

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Flatten,MaxPooling2D,BatchNormalization,Activation, Conv2D, Dropout

def tfl_model():
    input_shape =(81,81,3)
    
    model = Sequential()
    def conv_bn_relu(filters,**conv_kw):
        model.add(Conv2D(filters, use_bias=True, kernel_initializer='he_normal',padding='same', **conv_kw))
        model.add(BatchNormalization())
        model.add(Activation('relu'))

        
    def dense_bn_relu(units):
        model.add(Dense(units, use_bias=True, kernel_initializer='he_normal'))
        model.add(Dropout(0.15))
        model.add(BatchNormalization())
        model.add(Activation('relu'))
    
    def spatial_layer(count, filters): 
        for i in range(count):
            conv_bn_relu(filters,kernel_size=(3,3))
        conv_bn_relu(filters, kernel_size=(3,3),strides=(2,2))
    
    conv_bn_relu(32,kernel_size=(3,3),input_shape=input_shape)
    spatial_layer(1,32) 
    spatial_layer(2,64)
    spatial_layer(2,96) 

    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.15))
    model.add(Flatten())
    dense_bn_relu(96)
    model.add(Dense(2, activation='softmax'))

    return model

m = tfl_model()
m.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 81, 81, 32)        896
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 81, 81, 32)        128
# _________________________________________________________________
# activation_10 (Activation)   (None, 81, 81, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 81, 81, 32)        9248
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 81, 81, 32)        128
# _________________________________________________________________
# activation_11 (Activation)   (None, 81, 81, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 41, 41, 32)        9248
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 41, 41, 32)        128
# _________________________________________________________________
# activation_12 (Activation)   (None, 41, 41, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 41, 41, 64)        18496
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 41, 41, 64)        256
# _________________________________________________________________
# activation_13 (Activation)   (None, 41, 41, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 41, 41, 64)        36928
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 41, 41, 64)        256
# _________________________________________________________________
# activation_14 (Activation)   (None, 41, 41, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 21, 21, 64)        36928
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 21, 21, 64)        256
# _________________________________________________________________
# activation_15 (Activation)   (None, 21, 21, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 21, 21, 96)        55392
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 21, 21, 96)        384
# _________________________________________________________________
# activation_16 (Activation)   (None, 21, 21, 96)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 21, 21, 96)        83040
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 21, 21, 96)        384
# _________________________________________________________________
# activation_17 (Activation)   (None, 21, 21, 96)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 11, 11, 96)        83040
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 11, 11, 96)        384
# _________________________________________________________________
# activation_18 (Activation)   (None, 11, 11, 96)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 96)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 96)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2400)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 96)                230496
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 96)                0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 96)                384
# _________________________________________________________________
# activation_19 (Activation)   (None, 96)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 194
# =================================================================
# Total params: 566,594
# Trainable params: 565,250
# Non-trainable params: 1,344
# _________________________________________________________________

# %% [markdown]
# ## train

# %%
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam
data_dir = r'C:\Users\RENT\Desktop\Pojects\Mobileye Project\dataset'
datasets = {
    'val':load_tfl_data(join(data_dir,'val')),
    'train': load_tfl_data(join(data_dir,'train')),
    }
#prepare our model
m = tfl_model()
m.compile(optimizer=Adam(),loss =sparse_categorical_crossentropy,metrics=['accuracy'])


train,val = datasets['train'],datasets['val']
#train it, the model uses the 'train' dataset for learning. We evaluate the "goodness" of the model, by predicting the label of the images in the val dataset.
history=m.fit(train['images'],train['labels'],validation_data=(val['images'],val['labels']),epochs = 10, batch_size=100)

#compare train vs val acccuracy, 
# why is val_accuracy not as good as train accuracy? are we overfitting?
epochs = history.history
epochs['train_acc'] = epochs['acc']
plt.figure(figsize=(10,10))
for k in ['train_acc','val_acc']:
    plt.plot(range(len(epochs[k])), epochs[k],label=k)

plt.legend();

## evaluate and predict
# Now thet we have a model we can use to predict results on the validation dataset.
# 1. What can say about example that fail prediction? can we find patterns that are common for failure cases?

import seaborn as sbn
predictions = m.predict(val['images'])
# sbn.http://localhost:8888/lab 
# evaluate-and-predict.distplot(predictions[:,0]);

predicted_label = np.argmax(predictions, axis=-1)
print ('accuracy:', np.mean(predicted_label==val['labels']))
# Out:
# Train on 7136 samples, validate on 484 samples
# Epoch 1/10
# 7136/7136 [==============================] - 628s 88ms/sample - loss: 0.4432 - acc: 0.8003 - val_loss: 1.9353 - val_acc: 0.5248
# Epoch 2/10
# 7136/7136 [==============================] - 623s 87ms/sample - loss: 0.2845 - acc: 0.8852 - val_loss: 0.6883 - val_acc: 0.7066
# Epoch 3/10
# 7136/7136 [==============================] - 683s 96ms/sample - loss: 0.2215 - acc: 0.9142 - val_loss: 0.5255 - val_acc: 0.7769
# Epoch 4/10
# 7136/7136 [==============================] - 665s 93ms/sample - loss: 0.1858 - acc: 0.9276 - val_loss: 0.3267 - val_acc: 0.8512
# Epoch 5/10
# 7136/7136 [==============================] - 646s 91ms/sample - loss: 0.1556 - acc: 0.9392 - val_loss: 0.3886 - val_acc: 0.8657
# Epoch 6/10
# 7136/7136 [==============================] - 677s 95ms/sample - loss: 0.1242 - acc: 0.9522 - val_loss: 0.4184 - val_acc: 0.8326
# Epoch 7/10
# 7136/7136 [==============================] - 698s 98ms/sample - loss: 0.1015 - acc: 0.9630 - val_loss: 0.3541 - val_acc: 0.8678
# Epoch 8/10
# 7136/7136 [==============================] - 737s 103ms/sample - loss: 0.1021 - acc: 0.9608 - val_loss: 0.4483 - val_acc: 0.8512
# Epoch 9/10
# 7136/7136 [==============================] - 733s 103ms/sample - loss: 0.0681 - acc: 0.9738 - val_loss: 0.4780 - val_acc: 0.8430
# Epoch 10/10
# 7136/7136 [==============================] - 647s 91ms/sample - loss: 0.0680 - acc: 0.9770 - val_loss: 0.6294 - val_acc: 0.8120

# %%
viz_my_data(num=(6,6),predictions=predictions[:,1],**val);

### Seek ways to improve resutls 
# 1. Try to play with diffferent models , increase / decrease the number of conv layers or number of  filters. you'll need to find a balanced model that is sufficiently large but minimzes overfit
#     - try to enable tensorboard vizualization (see keras/ tensorboard doc) to help you carry the analysis
# 2. Data augmentation: feed your network with more examples by using data augmentation techniques: such as horizontal image flip, noise, etc

# %%
# # Load the TensorBoard notebook extension
# %load_ext tensorboard
# import tensorflow as tf
# import datetime

# mnist = tf.keras.datasets.mnist

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# ### Saving the model
# After we trained our model and made predictions with it, we will now want to save the **architecture** together with its learned **weights** in order for us to be able to use it in the TFL manager.
# The architecture will be saved as a json, the weights in the h5 format:

# %%
m.save("model.h5")

# %%
# If you want to make sure that this model can be used on different operating systems and different
# versions of keras or tensorflow, this is the better way to save. For this project the simpler
# method above should work fine.

# json_filename = 'model.json'
# h5_filename   = 'weights.h5'
# # create a json with the model architecture
# model_json = m.to_json()
# # save the json to disk
# with open(json_filename, 'w') as f:
#     f.write(model_json)
# # save the model's weights:
# m.save_weights(h5_filename)
# print(" ".join(["Model saved to", json_filename, h5_filename]))
# Out:
# Model saved to model.json weights.h5

# %% [markdown]
# ### Loading the model

# %%
from tensorflow.keras.models import load_model
loaded_model = load_model("model.h5")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-26-7d56137d8b22> in <module>
#       1 from tensorflow.keras.models import load_model
# ----> 2 loaded_model = load_model("model.h5")
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\keras\saving\save.py in load_model(filepath, custom_objects, compile)
#     144
#     145   if isinstance(filepath, six.string_types):
# --> 146     loader_impl.parse_saved_model(filepath)
#     147     return saved_model_load.load(filepath, compile)
#     148
#
# ~\AppData\Roaming\Python\Python37\site-packages\tensorflow_core\python\saved_model\loader_impl.py in parse_saved_model(export_dir)
#      81                   (export_dir,
#      82                    constants.SAVED_MODEL_FILENAME_PBTXT,
# ---> 83                    constants.SAVED_MODEL_FILENAME_PB))
#      84
#      85
#
# OSError: SavedModel file does not exist at: model.h5/{saved_model.pbtxt|saved_model.pb}

# %% [markdown]
# If you use the more robust method of saving above, this is how you load the model.

# %%
with open(json_filename, 'r') as j:
    loaded_json = j.read()

# load the model architecture: 
loaded_model = keras.models.model_from_json(loaded_json)
#load the weights:
loaded_model.load_weights(h5_filename)
print(" ".join(["Model loaded from", json_filename, h5_filename]))
# Out:
#   File "<ipython-input-9-5661b580b34c>", line 1
#     If you use the more robust method of saving above, this is how you load the model.
#          ^
# SyntaxError: invalid syntax

# %%
# code copied from the training evaluation: 
l_predictions = loaded_model.predict(val['images'])
sbn.distplot(l_predictions[:,0]);

l_predicted_label = np.argmax(l_predictions, axis=-1)
print ('accuracy:', np.mean(l_predicted_label==val['labels']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6b0ba52adc22> in <module>
#       1 # code copied from the training evaluation:
# ----> 2 l_predictions = loaded_model.predict(val['images'])
#       3 sbn.distplot(l_predictions[:,0]);
#       4
#       5 l_predicted_label = np.argmax(l_predictions, axis=-1)
#
# NameError: name 'loaded_model' is not defined
